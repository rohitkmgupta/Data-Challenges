# %%
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
df=pd.read_csv('items.csv',error_bad_lines=False)
# Out:
# b'Skipping line 18656: expected 25 fields, saw 26\nSkipping line 20210: expected 25 fields, saw 26\nSkipping line 24284: expected 25 fields, saw 26\nSkipping line 25671: expected 25 fields, saw 26\nSkipping line 32052: expected 25 fields, saw 26\n'
# b'Skipping line 33654: expected 25 fields, saw 26\nSkipping line 37586: expected 25 fields, saw 26\nSkipping line 43319: expected 25 fields, saw 26\nSkipping line 61269: expected 25 fields, saw 26\n'
# b'Skipping line 72528: expected 25 fields, saw 26\nSkipping line 73591: expected 25 fields, saw 26\nSkipping line 89555: expected 25 fields, saw 26\nSkipping line 91553: expected 25 fields, saw 26\n'
# b'Skipping line 108665: expected 25 fields, saw 26\nSkipping line 116677: expected 25 fields, saw 26\nSkipping line 117456: expected 25 fields, saw 26\nSkipping line 120957: expected 25 fields, saw 26\nSkipping line 128068: expected 25 fields, saw 26\n'
# ...

# %%
df.head()
# Out:
#   item_number brand_id       brand_name  brand_tier_id  category_id  \
# 0    20042271    32737         Lucie Lu            6.0        346.0
# 1    20028301    36671   Isabel + Alice            7.0        346.0
# 2    22612071     2804      Free People            7.0        743.0
# 3    22612052      982  Banana Republic            7.0        329.0
# 4    22612043      128              Gap            4.0        356.0
#
#          category_name category_tier_id  itemization_category_group_id  \
# 0         Casual Dress               10                           42.0
# 1         Casual Dress               10                           42.0
# 2  Short Sleeve Blouse                9                           39.0
# 3     Pullover Sweater               10                           40.0
# 4                Jeans               10                           77.0
#
#    sizing_id  size_tier_id         ...          primary_material  \
# ...

# %%
pdp = df[df.purchased_at.notnull()]

# %%
pdp.head()
# Out:
#    item_number brand_id   brand_name  brand_tier_id  category_id  \
# 2     22612071     2804  Free People            7.0        743.0
# 10    22612021      279     Old Navy            4.0        356.0
# 19    22605481     1511  Lane Bryant            4.0        348.0
# 22    22604152      164      J Brand           28.0        356.0
# 26    22604033     7884         Zara            5.0        745.0
#
#           category_name category_tier_id  itemization_category_group_id  \
# 2   Short Sleeve Blouse                9                           39.0
# 10                Jeans               10                           77.0
# 19         Casual Skirt                9                           69.0
# 22                Jeans               10                           77.0
# 26   Long Sleeve Blouse               10                           39.0
#
#     sizing_id  size_tier_id         ...          primary_material  \
# 2       778.0          24.0         ...                    Cotton
# ...

# %%
pdp.to_csv('pdp.csv')

# %%
pdp['purchased_at'] = pd.to_datetime(pdp['purchased_at'])
pdp['listed_at'] = pd.to_datetime(pdp['listed_at'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
