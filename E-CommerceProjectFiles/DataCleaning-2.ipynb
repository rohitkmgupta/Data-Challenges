# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv('pdp.csv',encoding="ISO-8859-1", error_bad_lines=False)
df.head()
df.shape
# Out:
# (335539, 26)

# %%
df['listed_at'] = pd.to_datetime(df['listed_at'])
df['purchased_at'] = pd.to_datetime(df['purchased_at'])

# %%
df['time_to_sell']=df['purchased_at']-df['listed_at']

# %%
df.head()
# Out:
#    Unnamed: 0  item_number  brand_id   brand_name  brand_tier_id  category_id  \
# 0           2     22612071      2804  Free People            7.0        743.0
# 1          10     22612021       279     Old Navy            4.0        356.0
# 2          19     22605481      1511  Lane Bryant            4.0        348.0
# 3          22     22604152       164      J Brand           28.0        356.0
# 4          26     22604033      7884         Zara            5.0        745.0
#
#          category_name  category_tier_id  itemization_category_group_id  \
# 0  Short Sleeve Blouse                 9                           39.0
# 1                Jeans                10                           77.0
# 2         Casual Skirt                 9                           69.0
# 3                Jeans                10                           77.0
# 4   Long Sleeve Blouse                10                           39.0
#
# ...

# %%
df.drop(df.item_number.isnull())
# Out:
#         Unnamed: 0  item_number  brand_id                  brand_name  \
# 1               10     22612021       279                    Old Navy
# 2               19     22605481      1511                 Lane Bryant
# 3               22     22604152       164                     J Brand
# 4               26     22604033      7884                        Zara
# 5               28     22603581       279                    Old Navy
# 6               36     22602714      7743                   Blue Bird
# 7               42     22601884     11089               Sarah Spencer
# 8               46     22601183      1023                  Lands' End
# 9               49     22600973      8033                 Marina Luna
# 10              64     22599793       984                 Lucky Brand
# 11              84     22597354      2749             Jessica Simpson
# 12              87     22596913     11935          Perseption Concept
# ...

# %%
df.drop(df.brand_id.isnull())
# Out:
#         Unnamed: 0  item_number  brand_id                  brand_name  \
# 1               10     22612021       279                    Old Navy
# 2               19     22605481      1511                 Lane Bryant
# 3               22     22604152       164                     J Brand
# 4               26     22604033      7884                        Zara
# 5               28     22603581       279                    Old Navy
# 6               36     22602714      7743                   Blue Bird
# 7               42     22601884     11089               Sarah Spencer
# 8               46     22601183      1023                  Lands' End
# 9               49     22600973      8033                 Marina Luna
# 10              64     22599793       984                 Lucky Brand
# 11              84     22597354      2749             Jessica Simpson
# 12              87     22596913     11935          Perseption Concept
# ...

# %%
df.drop(df.brand_name.isnull())
# Out:
#         Unnamed: 0  item_number  brand_id                  brand_name  \
# 1               10     22612021       279                    Old Navy
# 2               19     22605481      1511                 Lane Bryant
# 3               22     22604152       164                     J Brand
# 4               26     22604033      7884                        Zara
# 5               28     22603581       279                    Old Navy
# 6               36     22602714      7743                   Blue Bird
# 7               42     22601884     11089               Sarah Spencer
# 8               46     22601183      1023                  Lands' End
# 9               49     22600973      8033                 Marina Luna
# 10              64     22599793       984                 Lucky Brand
# 11              84     22597354      2749             Jessica Simpson
# 12              87     22596913     11935          Perseption Concept
# ...

# %%
df.drop(df.brand_id.isnull())
# Out:
#         Unnamed: 0  item_number  brand_id                  brand_name  \
# 1               10     22612021       279                    Old Navy
# 2               19     22605481      1511                 Lane Bryant
# 3               22     22604152       164                     J Brand
# 4               26     22604033      7884                        Zara
# 5               28     22603581       279                    Old Navy
# 6               36     22602714      7743                   Blue Bird
# 7               42     22601884     11089               Sarah Spencer
# 8               46     22601183      1023                  Lands' End
# 9               49     22600973      8033                 Marina Luna
# 10              64     22599793       984                 Lucky Brand
# 11              84     22597354      2749             Jessica Simpson
# 12              87     22596913     11935          Perseption Concept
# ...

# %%
df.drop(df.brand_name.isnull())
# Out:
#         Unnamed: 0  item_number  brand_id                  brand_name  \
# 1               10     22612021       279                    Old Navy
# 2               19     22605481      1511                 Lane Bryant
# 3               22     22604152       164                     J Brand
# 4               26     22604033      7884                        Zara
# 5               28     22603581       279                    Old Navy
# 6               36     22602714      7743                   Blue Bird
# 7               42     22601884     11089               Sarah Spencer
# 8               46     22601183      1023                  Lands' End
# 9               49     22600973      8033                 Marina Luna
# 10              64     22599793       984                 Lucky Brand
# 11              84     22597354      2749             Jessica Simpson
# 12              87     22596913     11935          Perseption Concept
# ...

# %%
df.drop(df.brand_tier_id.isnull())
# Out:
#         Unnamed: 0  item_number  brand_id                  brand_name  \
# 1               10     22612021       279                    Old Navy
# 2               19     22605481      1511                 Lane Bryant
# 3               22     22604152       164                     J Brand
# 4               26     22604033      7884                        Zara
# 5               28     22603581       279                    Old Navy
# 6               36     22602714      7743                   Blue Bird
# 7               42     22601884     11089               Sarah Spencer
# 8               46     22601183      1023                  Lands' End
# 9               49     22600973      8033                 Marina Luna
# 10              64     22599793       984                 Lucky Brand
# 11              84     22597354      2749             Jessica Simpson
# 12              87     22596913     11935          Perseption Concept
# ...

# %%
df.drop(df.category_id.isnull())
# Out:
#         Unnamed: 0  item_number  brand_id                  brand_name  \
# 1               10     22612021       279                    Old Navy
# 2               19     22605481      1511                 Lane Bryant
# 3               22     22604152       164                     J Brand
# 4               26     22604033      7884                        Zara
# 5               28     22603581       279                    Old Navy
# 6               36     22602714      7743                   Blue Bird
# 7               42     22601884     11089               Sarah Spencer
# 8               46     22601183      1023                  Lands' End
# 9               49     22600973      8033                 Marina Luna
# 10              64     22599793       984                 Lucky Brand
# 11              84     22597354      2749             Jessica Simpson
# 12              87     22596913     11935          Perseption Concept
# ...

# %%
df[df.quality_reason_codes.isnull()]
# Out:
#         Unnamed: 0  item_number  brand_id                  brand_name  \
# 0                2     22612071      2804                 Free People
# 1               10     22612021       279                    Old Navy
# 2               19     22605481      1511                 Lane Bryant
# 4               26     22604033      7884                        Zara
# 6               36     22602714      7743                   Blue Bird
# 7               42     22601884     11089               Sarah Spencer
# 9               49     22600973      8033                 Marina Luna
# 10              64     22599793       984                 Lucky Brand
# 13              88     22596864      2861                  Avalanche
# 14              93     22596434      2804                 Free People
# 15             105     22595591     10678              Divided by H&M
# 16             112     22594772      8022                       PrAna
# ...

# %%
df['quality_reason_codes'].fillna('No Reason Specified',inplace=True)

# %%
df[df.quality_reason_codes.isnull()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, item_number, brand_id, brand_name, brand_tier_id, category_id, category_name, category_tier_id, itemization_category_group_id, sizing_id, size_tier_id, size_label, new_with_tags, quality_code, quality_reason_codes, merchandising_department, primary_material, secondary_material, original_msrp, original_price, payout_policy, seasonal_slope_30d, relisted, warehouse_id, listed_at, purchased_at, time_to_sell]
# Index: []
#
# [0 rows x 27 columns]

# %%
df[df.quality_reason_codes.isnull()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, item_number, brand_id, brand_name, brand_tier_id, category_id, category_name, category_tier_id, itemization_category_group_id, sizing_id, size_tier_id, size_label, new_with_tags, quality_code, quality_reason_codes, merchandising_department, primary_material, secondary_material, original_msrp, original_price, payout_policy, seasonal_slope_30d, relisted, warehouse_id, listed_at, purchased_at, time_to_sell]
# Index: []
#
# [0 rows x 27 columns]

# %%
df[df.merchandising_department.isnull()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, item_number, brand_id, brand_name, brand_tier_id, category_id, category_name, category_tier_id, itemization_category_group_id, sizing_id, size_tier_id, size_label, new_with_tags, quality_code, quality_reason_codes, merchandising_department, primary_material, secondary_material, original_msrp, original_price, payout_policy, seasonal_slope_30d, relisted, warehouse_id, listed_at, purchased_at, time_to_sell]
# Index: []
#
# [0 rows x 27 columns]

# %%
list(df)
# Out:
# ['Unnamed: 0',
#  'item_number',
#  'brand_id',
#  'brand_name',
#  'brand_tier_id',
#  'category_id',
#  'category_name',
#  'category_tier_id',
#  'itemization_category_group_id',
#  'sizing_id',
#  'size_tier_id',
#  'size_label',
#  'new_with_tags',
#  'quality_code',
#  'quality_reason_codes',
#  'merchandising_department',
#  'primary_material',
#  'secondary_material',
#  'original_msrp',
#  'original_price',
#  'payout_policy',
#  'seasonal_slope_30d',
#  'relisted',
#  'warehouse_id',
#  'listed_at',
#  'purchased_at',
#  'time_to_sell']

# %%
df[df.primary_material.isnull()]
# Out:
#         Unnamed: 0  item_number  brand_id                     brand_name  \
# 4               26     22604033      7884                           Zara
# 26             185     22589464      1472                           Puma
# 37             212     22586241      9886                         Bamboo
# 44             248     22582744      9566          Diane von Furstenberg
# 51             279     22580374      8022                          PrAna
# 59             310     22578452         7                         Adidas
# 63             327     22577662      1249                     Ann Taylor
# 65             330     22577661      7884                           Zara
# 76             437     22574151     10618                          Venus
# 89             515     22571633     20543               Anne Klein Sport
# 91             523     22571462     11134                   River Island
# 93             536     22571112     14274                       Espresso
# ...

# %%
df.shape
# Out:
# (335539, 27)

# %%
df['primary_material'].fillna('No Primary Material Specified',inplace=True)

# %%
df[df.primary_material.isnull()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, item_number, brand_id, brand_name, brand_tier_id, category_id, category_name, category_tier_id, itemization_category_group_id, sizing_id, size_tier_id, size_label, new_with_tags, quality_code, quality_reason_codes, merchandising_department, primary_material, secondary_material, original_msrp, original_price, payout_policy, seasonal_slope_30d, relisted, warehouse_id, listed_at, purchased_at, time_to_sell]
# Index: []
#
# [0 rows x 27 columns]

# %%
df[df.secondary_material.isnull()]
# Out:
#         Unnamed: 0  item_number  brand_id                  brand_name  \
# 1               10     22612021       279                    Old Navy
# 2               19     22605481      1511                 Lane Bryant
# 4               26     22604033      7884                        Zara
# 5               28     22603581       279                    Old Navy
# 10              64     22599793       984                 Lucky Brand
# 13              88     22596864      2861                  Avalanche
# 14              93     22596434      2804                 Free People
# 18             128     22593854     13156                         Clu
# 19             129     22593792       221               Liz Claiborne
# 22             158     22591252      1269      Levi Strauss Signature
# 23             173     22590272     14101   Emanuel by Emanuel Ungaro
# 25             178     22589931      7884                        Zara
# ...

# %%
df['secondary_material'].fillna('No Secondary Material Specified',inplace=True)

# %%
df[df.secondary_material.isnull()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, item_number, brand_id, brand_name, brand_tier_id, category_id, category_name, category_tier_id, itemization_category_group_id, sizing_id, size_tier_id, size_label, new_with_tags, quality_code, quality_reason_codes, merchandising_department, primary_material, secondary_material, original_msrp, original_price, payout_policy, seasonal_slope_30d, relisted, warehouse_id, listed_at, purchased_at, time_to_sell]
# Index: []
#
# [0 rows x 27 columns]

# %%
list(df)
# Out:
# ['Unnamed: 0',
#  'item_number',
#  'brand_id',
#  'brand_name',
#  'brand_tier_id',
#  'category_id',
#  'category_name',
#  'category_tier_id',
#  'itemization_category_group_id',
#  'sizing_id',
#  'size_tier_id',
#  'size_label',
#  'new_with_tags',
#  'quality_code',
#  'quality_reason_codes',
#  'merchandising_department',
#  'primary_material',
#  'secondary_material',
#  'original_msrp',
#  'original_price',
#  'payout_policy',
#  'seasonal_slope_30d',
#  'relisted',
#  'warehouse_id',
#  'listed_at',
#  'purchased_at',
#  'time_to_sell']

# %%
df[df.original_msrp.isnull()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, item_number, brand_id, brand_name, brand_tier_id, category_id, category_name, category_tier_id, itemization_category_group_id, sizing_id, size_tier_id, size_label, new_with_tags, quality_code, quality_reason_codes, merchandising_department, primary_material, secondary_material, original_msrp, original_price, payout_policy, seasonal_slope_30d, relisted, warehouse_id, listed_at, purchased_at, time_to_sell]
# Index: []
#
# [0 rows x 27 columns]

# %%
df.shape
# Out:
# (335539, 27)

# %%
df[df.original_price.isnull()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, item_number, brand_id, brand_name, brand_tier_id, category_id, category_name, category_tier_id, itemization_category_group_id, sizing_id, size_tier_id, size_label, new_with_tags, quality_code, quality_reason_codes, merchandising_department, primary_material, secondary_material, original_msrp, original_price, payout_policy, seasonal_slope_30d, relisted, warehouse_id, listed_at, purchased_at, time_to_sell]
# Index: []
#
# [0 rows x 27 columns]

# %%
df[df.payout_policy.isnull()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, item_number, brand_id, brand_name, brand_tier_id, category_id, category_name, category_tier_id, itemization_category_group_id, sizing_id, size_tier_id, size_label, new_with_tags, quality_code, quality_reason_codes, merchandising_department, primary_material, secondary_material, original_msrp, original_price, payout_policy, seasonal_slope_30d, relisted, warehouse_id, listed_at, purchased_at, time_to_sell]
# Index: []
#
# [0 rows x 27 columns]

# %%
df[df.relisted.isnull()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, item_number, brand_id, brand_name, brand_tier_id, category_id, category_name, category_tier_id, itemization_category_group_id, sizing_id, size_tier_id, size_label, new_with_tags, quality_code, quality_reason_codes, merchandising_department, primary_material, secondary_material, original_msrp, original_price, payout_policy, seasonal_slope_30d, relisted, warehouse_id, listed_at, purchased_at, time_to_sell]
# Index: []
#
# [0 rows x 27 columns]

# %%
df[df.warehouse_id.isnull()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, item_number, brand_id, brand_name, brand_tier_id, category_id, category_name, category_tier_id, itemization_category_group_id, sizing_id, size_tier_id, size_label, new_with_tags, quality_code, quality_reason_codes, merchandising_department, primary_material, secondary_material, original_msrp, original_price, payout_policy, seasonal_slope_30d, relisted, warehouse_id, listed_at, purchased_at, time_to_sell]
# Index: []
#
# [0 rows x 27 columns]

# %%
df.head()
# Out:
#    Unnamed: 0  item_number  brand_id   brand_name  brand_tier_id  category_id  \
# 0           2     22612071      2804  Free People            7.0        743.0
# 1          10     22612021       279     Old Navy            4.0        356.0
# 2          19     22605481      1511  Lane Bryant            4.0        348.0
# 3          22     22604152       164      J Brand           28.0        356.0
# 4          26     22604033      7884         Zara            5.0        745.0
#
#          category_name  category_tier_id  itemization_category_group_id  \
# 0  Short Sleeve Blouse                 9                           39.0
# 1                Jeans                10                           77.0
# 2         Casual Skirt                 9                           69.0
# 3                Jeans                10                           77.0
# 4   Long Sleeve Blouse                10                           39.0
#
# ...

# %%
df.drop('Unnamed: 0', axis=1,inplace=True)

# %%
df.drop('item_number', axis=1,inplace=True)

# %%
df.drop('brand_id', axis=1,inplace=True)

# %%
df.drop('brand_name', axis=1,inplace=True)

# %%
df['brand_tier_id'].nunique()
# Out:
# 15

# %%
df.drop('brand_tier_id', axis=1,inplace=True)

# %%
df['category_id'].nunique()
# Out:
# 208

# %%
df.drop('category_id', axis=1,inplace=True)

# %%
df['category_name'].nunique()
# Out:
# 206

# %%
df.drop('category_name', axis=1,inplace=True)

# %%
df['category_tier_id'].nunique()
# Out:
# 7

# %%
df['itemization_category_group_id'].nunique()
# Out:
# 13

# %%
df.drop('itemization_category_group_id', axis=1,inplace=True)

# %%
df['sizing_id'].nunique()
# Out:
# 167

# %%
df.drop('sizing_id', axis=1,inplace=True)

# %%
df['size_tier_id'].nunique()
# Out:
# 1

# %%
df.drop('size_tier_id', axis=1,inplace=True)

# %%
df['size_label'].nunique()
# Out:
# 1081

# %%
df.drop('size_label', axis=1,inplace=True)

# %%
df['new_with_tags'].nunique()
# Out:
# 2

# %%
df['quality_code'].nunique()
# Out:
# 3

# %%
df['quality_reason_codes'].nunique()
# Out:
# 1007

# %%
df.drop('quality_reason_codes', axis=1,inplace=True)

# %%
df['merchandising_department'].nunique()
# Out:
# 7

# %%
df['primary_material'].nunique()
# Out:
# 186

# %%
df.drop('primary_material', axis=1,inplace=True)

# %%
df.drop('secondary_material', axis=1,inplace=True)

# %%
df['payout_policy'].nunique()
# Out:
# 2

# %%
df['relisted'].nunique()
# Out:
# 2

# %%
df['warehouse_id'].nunique()
# Out:
# 4

# %%
df.drop('listed_at', axis=1,inplace=True)

# %%
df.drop('purchased_at', axis=1,inplace=True)

# %%
df.head()
# Out:
#    category_tier_id  new_with_tags quality_code merchandising_department  \
# 0                 9            0.0           Q1                        X
# 1                10            0.0           Q1                    women
# 2                 9            0.0           Q1                     plus
# 3                10            0.0           Q2                        X
# 4                10            0.0           Q1                    women
#
#    original_msrp  original_price payout_policy  seasonal_slope_30d  relisted  \
# 0         9800.0          2299.0       upfront            0.005165       1.0
# 1         3500.0           899.0       upfront           -0.000691       1.0
# 2         3600.0          1099.0       upfront            0.001087       1.0
# 3        19600.0          3799.0       upfront           -0.000691       1.0
# 4         6000.0          1699.0       upfront            0.000145       1.0
#
#    warehouse_id time_to_sell
# 0           1.0     03:23:24
# ...

# %%
df.dtypes
# Out:
# category_tier_id                      int64
# new_with_tags                       float64
# quality_code                         object
# merchandising_department             object
# original_msrp                       float64
# original_price                      float64
# payout_policy                        object
# seasonal_slope_30d                  float64
# relisted                            float64
# warehouse_id                        float64
# time_to_sell                timedelta64[ns]
# dtype: object

# %%
df.head()
# Out:
#    category_tier_id  new_with_tags quality_code merchandising_department  \
# 0                 9            0.0           Q1                        X
# 1                10            0.0           Q1                    women
# 2                 9            0.0           Q1                     plus
# 3                10            0.0           Q2                        X
# 4                10            0.0           Q1                    women
#
#    original_msrp  original_price payout_policy  seasonal_slope_30d  relisted  \
# 0         9800.0          2299.0       upfront            0.005165       1.0
# 1         3500.0           899.0       upfront           -0.000691       1.0
# 2         3600.0          1099.0       upfront            0.001087       1.0
# 3        19600.0          3799.0       upfront           -0.000691       1.0
# 4         6000.0          1699.0       upfront            0.000145       1.0
#
#    warehouse_id time_to_sell
# 0           1.0     03:23:24
# ...

# %%
dummy= pd.get_dummies(df['category_tier_id'])

# %%
dummy.shape
# Out:
# (335539, 7)

# %%
dummy1=pd.get_dummies(df['new_with_tags'])

# %%
dummy1.shape
# Out:
# (335539, 2)

# %%
dummy2 = pd.get_dummies(df['quality_code'])

# %%
dummy3 =pd.get_dummies(df['merchandising_department'])

# %%
dummy4 = pd.get_dummies(df['payout_policy'])

# %%
dummy5= pd.get_dummies(df['relisted'])

# %%
dummy6= pd.get_dummies(df['warehouse_id'])

# %%
df =pd.concat([df,dummy,dummy1,dummy2,dummy3,dummy4,dummy5,dummy6],axis=1)

# %%
df.head()
# Out:
#    category_tier_id  new_with_tags quality_code merchandising_department  \
# 0                 9            0.0           Q1                        X
# 1                10            0.0           Q1                    women
# 2                 9            0.0           Q1                     plus
# 3                10            0.0           Q2                        X
# 4                10            0.0           Q1                    women
#
#    original_msrp  original_price payout_policy  seasonal_slope_30d  relisted  \
# 0         9800.0          2299.0       upfront            0.005165       1.0
# 1         3500.0           899.0       upfront           -0.000691       1.0
# 2         3600.0          1099.0       upfront            0.001087       1.0
# 3        19600.0          3799.0       upfront           -0.000691       1.0
# 4         6000.0          1699.0       upfront            0.000145       1.0
#
# ...

# %%
df.shape
# Out:
# (335539, 38)

# %%
df.to_csv('Dummy.csv')
